# %%
head(iris)
# Out:
#   Sepal.Length Sepal.Width Petal.Length Petal.Width Species
# 1 5.1          3.5         1.4          0.2         setosa
# 2 4.9          3.0         1.4          0.2         setosa
# 3 4.7          3.2         1.3          0.2         setosa
# 4 4.6          3.1         1.5          0.2         setosa
# 5 5.0          3.6         1.4          0.2         setosa
# 6 5.4          3.9         1.7          0.4         setosa

# %%
getwd
# Out:
# function ()
# .Internal(getwd())
# <bytecode: 0x7fb56fa06d70>
# <environment: namespace:base>

# %%
getwd()
# Out:
# [1] "/Users/mahdiebnali"

# %%
setwd("/Users/mahdiebnali/Downloads/csvfiles_original")

# %%
getwd()
# Out:
# [1] "/Users/mahdiebnali/Downloads/csvfiles_original"

# %%
data= read.csv("6-new_20190511174234.csv")
# Out:
# Warning message in read.table(file = file, header = header, sep = sep, quote = quote, :
# “line 2 appears to contain embedded nulls”Warning message in read.table(file = file, header = header, sep = sep, quote = quote, :
# “line 3 appears to contain embedded nulls”Warning message in read.table(file = file, header = header, sep = sep, quote = quote, :
# “line 4 appears to contain embedded nulls”Warning message in read.table(file = file, header = header, sep = sep, quote = quote, :
# “line 5 appears to contain embedded nulls”Warning message in scan(file = file, what = what, sep = sep, quote = quote, dec = dec, :
# “embedded nul(s) found in input”

# %%
head(data)
# Out:
#   Time Frames Acc_Pedal_Position Brake_Pedal_Position Brake_Pedal_Force
# 1 0.05 1829   0                  0                    0
# 2 0.10 1832   0                  0                    0
# 3 0.15 1835   0                  0                    0
# 4 0.20 1838   0                  0                    0
# 5 0.25 1841   0                  0                    0
# 6 0.30 1844   0                  0                    0
#   Veh_Speed   Steering_Wheel_Angle Steering_Wheel_Angle_Rate
# 1 0.033508420 2.079880              0.05850511
# 2 0.006869907 2.066833             -0.03438869
# 3 0.014546560 2.066833              0.00000000
# 4 0.022536040 2.066833              0.00000000
# 5 0.020114820 2.066833              0.00000000
# 6 0.011412590 2.066833              0.00000000
#   Steering_Wheel_Torque Auxiliary_Buttons_1 ⋯ SCC_Lane_Deviation_4
# 1 0.2093506             0                   ⋯ NA
# 2 0.1535645             0                   ⋯ NA
# ...

# %%
dim(data
   
   )
# Out:
# [1] 5713  367

# %%
e11[, 1:9, 14]
14
112 113 114 115 116 117 118 119 120 121 122 123 124 125
345
360 361 362 363 364 365 366 367]
# Out:
# Error in parse(text = x, srcfile = src): <text>:3:5: unexpected numeric constant
# 2: 14
# 3: 112 113
#        ^
# Traceback:

# %%
data_1= data[, c(1:9, 14, 112:125, 345, 360:367)]

# %%
dim(data_1)
# Out:
# [1] 5713   33

# %%
vo= data_1[, c("Time", "SCC_LogStreams_1")]

# %%
install.packages("ggplot2")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
install.packages("tidyverse")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(ggplot2)
ggplot(aes(x=Time,y=SCC_LogStreams_1),data=vo)+
  geom_point()+
  xlim(13,90)
# Out:
# Warning message:
# “Removed 4172 rows containing missing values (geom_point).”
# plot without title

# %%
plot(vo$Time,vo$SCC_LogStreams_1, type="l", lwd=1, xlab="time", ylab="concentration")
# Out:
# plot without title

# %%
vo_2= read.csv("6-new_20190412164208.csv")
# Out:
# Warning message in read.table(file = file, header = header, sep = sep, quote = quote, :
# “line 2 appears to contain embedded nulls”Warning message in read.table(file = file, header = header, sep = sep, quote = quote, :
# “line 3 appears to contain embedded nulls”Warning message in read.table(file = file, header = header, sep = sep, quote = quote, :
# “line 4 appears to contain embedded nulls”Warning message in read.table(file = file, header = header, sep = sep, quote = quote, :
# “line 5 appears to contain embedded nulls”Warning message in scan(file = file, what = what, sep = sep, quote = quote, dec = dec, :
# “embedded nul(s) found in input”

# %%
vo_2= vo_2[, c("Time", "SCC_LogStreams_1")]

# %%
plot(vo$Time,vo$SCC_LogStreams_1, type="l", lwd=1, xlab="time", ylab="concentration")
plot(vo_2$Time,vo_2$SCC_LogStreams_1, type="l", lwd=1, xlab="time", ylab="concentration")
# Out:
# plot without title
# plot without title

# %%
vo_3= read.csv("6-new_20190410115448.csv")
# Out:
# Warning message in read.table(file = file, header = header, sep = sep, quote = quote, :
# “line 2 appears to contain embedded nulls”Warning message in read.table(file = file, header = header, sep = sep, quote = quote, :
# “line 3 appears to contain embedded nulls”Warning message in read.table(file = file, header = header, sep = sep, quote = quote, :
# “line 4 appears to contain embedded nulls”Warning message in read.table(file = file, header = header, sep = sep, quote = quote, :
# “line 5 appears to contain embedded nulls”Warning message in scan(file = file, what = what, sep = sep, quote = quote, dec = dec, :
# “embedded nul(s) found in input”

# %%
vo_3= vo_3[, c("Time", "SCC_LogStreams_1")]

# %%
plot(vo$Time,vo$SCC_LogStreams_1, type="l", lwd=1, xlab="time", ylab="concentration")
plot(vo_2$Time,vo_2$SCC_LogStreams_1, type="l", lwd=1, xlab="time", ylab="concentration")
plot(vo_3$Time,vo_3$SCC_LogStreams_1, type="l", lwd=1, xlab="time", ylab="concentration")
# Out:
# plot without title
# plot without title
# plot without title

# %%
# Out:
# Error in head(vo): object 'vo' not found
# Traceback:
#
# 1. head(vo)
